# %% [markdown]
# # My first notebook

# %% [markdown]
# This is **my first ever** notebook 🚀

# %%
world = 'Jupyter'

# %% [markdown]
# Apparently, the variable `i` defined above should exist in the next code cell 👇. Now, it turns out, if you want to make the variable accessible to next cells, you firstly need to run the earlier ones.

# %%
print("Hello %s!" % world)
# Out:
# Hello Jupyter!

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 1, 300)
for w in range(2, 6, 2):
    plt.plot(x, np.sin(np.pi*x)*np.sin(2*w*np.pi*x))
